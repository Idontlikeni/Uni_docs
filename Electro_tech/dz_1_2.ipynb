# %%
import numpy as np;
import matplotlib.pyplot as plt 
phi = np.array([0, -14, -9.4013, -12.693, 0.3, 0])
R = np.array([0, 0, 62, 15+62, 15+62, 15+62+28])
fig, ax = plt.subplots()
ax.scatter(R, phi)
ax.plot(R, phi)
plt.show()
