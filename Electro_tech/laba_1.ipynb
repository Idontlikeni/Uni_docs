# %%
import numpy as np;
import matplotlib.pyplot as plt 
I = np.array([520.25, 340, 253.04, 201.21, 167.09, 142.86, 124.77])
U = np.array([61.89, 167.83, 219.62, 250.31, 270.52, 284.86, 295.58])
fig, ax = plt.subplots()
ax.scatter(I, U)
ax.plot(I, U)
plt.show()

# %%
P = U * I / 1000
P
# Out:
# array([32.1982725, 57.0622   , 55.5726448, 50.3648751, 45.2011868,
#        40.6950996, 36.8795166])

# %%
R = np.array([118, 493, 868, 1244, 1619, 1994, 2369])
fig, ax = plt.subplots()
ax.scatter(R, P)
ax.plot(R, P)
plt.show()

# %%
V = np.array([2, -146 / 1000, -1.35, -2.26, 4.74, 2.37, 0])
Rs = np.array([0, 398, 603, 1333, 1333, 1524, 1928])
fig, ax = plt.subplots()
ax.scatter(Rs, V)
ax.plot(Rs, V)
ax.scatter(Rs, np.array([-2.26 for _ in range(7)]))
plt.show()
