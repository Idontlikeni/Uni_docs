# %%
M = 18
S = 11
q = []
qt = []
jkr = []
def jk(a, b):
    s = a + b
    if s == "00": return "0x"
    if s == "01": return "1x"
    if s == "10": return "x1"
    if s == "11": return "x0"

for i in range(M):
    q.append(bin(i)[2:].rjust(5, '0'))
    qt.append(bin((i + S)%M)[2:].rjust(5, '0'))
    jkr.append([jk(q[i][j], qt[i][j]) for j in range(5)])
    print(i, bin(i)[2:].rjust(5, '0'), (i + S)%M, bin((i + S)%M)[2:].rjust(5, '0'), *jkr[i])
# Out:
# 0 00000 11 01011 0x 1x 0x 1x 1x
# 1 00001 12 01100 0x 1x 1x 0x x1
# 2 00010 13 01101 0x 1x 1x x1 1x
# 3 00011 14 01110 0x 1x 1x x0 x1
# 4 00100 15 01111 0x 1x x0 1x 1x
# 5 00101 16 10000 1x 0x x1 0x x1
# 6 00110 17 10001 1x 0x x1 x1 1x
# 7 00111 0 00000 0x 0x x1 x1 x1
# 8 01000 1 00001 0x x1 0x 0x 1x
# 9 01001 2 00010 0x x1 0x 1x x1
# 10 01010 3 00011 0x x1 0x x0 1x
# 11 01011 4 00100 0x x1 1x x1 x1
# 12 01100 5 00101 0x x1 x0 0x 1x
# 13 01101 6 00110 0x x1 x0 1x x1
# 14 01110 7 00111 0x x1 x0 x0 1x
# 15 01111 8 01000 0x x0 x1 x1 x1
# 16 10000 9 01001 x1 1x 0x 0x 1x
# 17 10001 10 01010 x1 1x 0x 1x x1

# %%
counter = 4 # D Триггер
for elem in list(zip(*qt)):
    f = "".join(elem) # .ljust(32, 'x')
    print
    # print(f)
    # print(len(f))
    rows = ['00', '01', '11', '10']
    cols = ['000', '001', '011', '010', '110', '111', '101', '100']
    arr = [['x' for __ in range(len(cols))] for _ in range(len(rows))]
    for i in range(M):
        s = q[i]
        arr[rows.index(s[:2])][cols.index(s[2:])] = f[i]
    print(f"Q:{counter}")
    counter -= 1
    for i in range(4):
        print("".join(arr[i]))
    print("----------------")
# Out:
# Q:4
# 00001010
# 00000000
# xxxxxxxx
# 00xxxxxx
# ----------------
# Q:3
# 11110001
# 00000100
# xxxxxxxx
# 11xxxxxx
# ----------------
# Q:2
# 01110001
# 00101011
# xxxxxxxx
# 00xxxxxx
# ----------------
# Q:1
# 10100001
# 01011010
# xxxxxxxx
# 01xxxxxx
# ----------------
# Q:0
# 10011001
# 10011001
# xxxxxxxx
# 10xxxxxx
# ----------------

# %%
counter = 4 # jk trigger
for elem in list(zip(*jkr)):
    
    element = list(zip(*elem))
    # print(element)
    rows = ['00', '01', '11', '10']
    cols = ['000', '001', '011', '010', '110', '111', '101', '100']
    arr = [['x' for __ in range(len(cols))] for _ in range(len(rows))]
    for i in range(M):
        s = q[i]
        arr[rows.index(s[:2])][cols.index(s[2:])] = element[0][i]
    print(f"S(j):{counter}")
    for i in range(4):
        print("".join(arr[i]))

    arr = [['x' for __ in range(len(cols))] for _ in range(len(rows))]
    for i in range(M):
        s = q[i]
        arr[rows.index(s[:2])][cols.index(s[2:])] = element[1][i]
    print(f"S(k):{counter}")
    for i in range(4):
        print("".join(arr[i]))
    print("----------------")
    counter -= 1
# Out:
# S(j):4
# 00001010
# 00000000
# xxxxxxxx
# xxxxxxxx
# S(k):4
# xxxxxxxx
# xxxxxxxx
# xxxxxxxx
# 11xxxxxx
# ----------------
# S(j):3
# 11110001
# xxxxxxxx
# xxxxxxxx
# 11xxxxxx
# S(k):3
# xxxxxxxx
# 11111011
# xxxxxxxx
# xxxxxxxx
# ----------------
# S(j):2
# 0111xxxx
# 0010xxxx
# xxxxxxxx
# 00xxxxxx
# S(k):2
# xxxx1110
# xxxx0100
# xxxxxxxx
# xxxxxxxx
# ----------------
# S(j):1
# 10xxxx01
# 01xxxx10
# xxxxxxxx
# 01xxxxxx
# S(k):1
# xx0111xx
# xx1001xx
# xxxxxxxx
# xxxxxxxx
# ----------------
# S(j):0
# 1xx11xx1
# 1xx11xx1
# xxxxxxxx
# 1xxxxxxx
# S(k):0
# x11xx11x
# x11xx11x
# xxxxxxxx
# x1xxxxxx
# ----------------
