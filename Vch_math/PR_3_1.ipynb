# %% [markdown]
# 1 и 2 уравнение
# 1 - отделить корень графически
# 2 - аналитически
# уточнить методом половинного деления
# $\varepsilon = 0,01$
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt 
from math import atan, pi, abs

def f1(x):
    return pi/2 - atan(x) + 2*x - 1
def f2(x):
    return 3*x**4 + 4*x**3 - 12*x**2 + 1
e = 0.01

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \begin{gather}
# y = arcctg(x) + 2x + 1 \\
# [a_{0}, b_{0}] = [-2, 0]
# \end{gather}
# $$

# %%
a = -2
b = 0
x_prev = None
x = None
while 1:
    x_mid = (b + a)/2
    
    f = f1(x_mid)
    print(a, b, x_mid, f, b-a)
    if f > 0:
        b = x_mid
    elif f < 0:
        a = x_mid
    else:
        print("answer: ", x_mid)
        break
    if x_prev is None:
        x_prev = x_mid
    else:
        if abs(x_prev - x_mid) <= 0.01:
            print("x: ", x_mid)
            x = x_mid
            break
    x_prev = x_mid
# Out:
# -2 0 -1.0 -0.6438055098076552 2
# -1.0 0 -0.5 0.03444393579570271 1.0
# -1.0 -0.5 -0.75 -0.2857025644118192 0.5
# -0.75 -0.5 -0.625 -0.120604357861541 0.25
# -0.625 -0.5 -0.5625 -0.04181421289436571 0.125
# -0.5625 -0.5 -0.53125 -0.0033697221486979068 0.0625
# -0.53125 -0.5 -0.515625 0.015615657117657555 0.03125
# -0.53125 -0.515625 -0.5234375 0.006142651022750467 0.015625
# x:  -0.5234375

# %%
import matplotlib.pyplot as plt 
fig, ax = plt.subplots()
ax.scatter(x, y)
ax.plot(x, y_calc)
plt.show()

# %%
a = -2
b = 0
x_prev = None
while 1:
    x_mid = (b + a)/2
    
    f = f2(x_mid)
    print(a, b, x_mid, f, b-a)
    if f > 0:
        b = x_mid
    elif f < 0:
        a = x_mid
    else:
        print("x: ", x_mid)
        break
    if x_prev is None:
        x_prev = x_mid
    else:
        if abs(x_prev - x_mid) <= 0.01:
            print("x: ", x_mid)
            break
    x_prev = x_mid
